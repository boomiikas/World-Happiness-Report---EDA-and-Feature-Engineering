# %%
# !{sys.executable} -m pip install sympy
# Out:
# '{sys.executable}' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('world_happiness_2024.csv')

# %%
df.head(10)
# Out:
#   Country name            Regional indicator  Ladder score  upperwhisker  \
# 0      Finland                Western Europe         7.741         7.815
# 1      Denmark                Western Europe         7.583         7.665
# 2      Iceland                Western Europe         7.525         7.618
# 3       Sweden                Western Europe         7.344         7.422
# 4       Israel  Middle East and North Africa         7.341         7.405
# 5  Netherlands                Western Europe         7.319         7.383
# 6       Norway                Western Europe         7.302         7.389
# 7   Luxembourg                Western Europe         7.122         7.213
# 8  Switzerland                Western Europe         7.060         7.147
# 9    Australia         North America and ANZ         7.057         7.141
#
#    lowerwhisker  Log GDP per capita  Social support  Healthy life expectancy  \
# 0         7.667               1.844           1.572                    0.695
# ...

# %%
df.shape
# Out:
# (143, 12)

# %%
df.columns
# Out:
# Index(['Country name', 'Regional indicator', 'Ladder score', 'upperwhisker',
#        'lowerwhisker', 'Log GDP per capita', 'Social support',
#        'Healthy life expectancy', 'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Dystopia + residual'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 143 entries, 0 to 142
# Data columns (total 12 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Country name                  143 non-null    object
#  1   Regional indicator            143 non-null    object
#  2   Ladder score                  143 non-null    float64
#  3   upperwhisker                  143 non-null    float64
#  4   lowerwhisker                  143 non-null    float64
#  5   Log GDP per capita            140 non-null    float64
#  6   Social support                140 non-null    float64
#  7   Healthy life expectancy       140 non-null    float64
#  8   Freedom to make life choices  140 non-null    float64
#  9   Generosity                    140 non-null    float64
#  10  Perceptions of corruption     140 non-null    float64
#  11  Dystopia + residual           140 non-null    float64
# dtypes: float64(10), object(2)
# ...

# %%
df.isnull().sum()
# Out:
# Country name                    0
# Regional indicator              0
# Ladder score                    0
# upperwhisker                    0
# lowerwhisker                    0
# Log GDP per capita              3
# Social support                  3
# Healthy life expectancy         3
# Freedom to make life choices    3
# Generosity                      3
# Perceptions of corruption       3
# Dystopia + residual             3
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#        Ladder score  upperwhisker  lowerwhisker  Log GDP per capita  \
# count    143.000000    143.000000    143.000000          140.000000
# mean       5.527580      5.641175      5.413972            1.378807
# std        1.170717      1.155008      1.187133            0.425098
# min        1.721000      1.775000      1.667000            0.000000
# 25%        4.726000      4.845500      4.606000            1.077750
# 50%        5.785000      5.895000      5.674000            1.431500
# 75%        6.416000      6.507500      6.319000            1.741500
# max        7.741000      7.815000      7.667000            2.141000
#
#        Social support  Healthy life expectancy  Freedom to make life choices  \
# count      140.000000               140.000000                    140.000000
# mean         1.134329                 0.520886                      0.620621
# std          0.333317                 0.164923                      0.162492
# ...

# %%
df['Country name'].unique()
# Out:
# array(['Finland', 'Denmark', 'Iceland', 'Sweden', 'Israel', 'Netherlands',
#        'Norway', 'Luxembourg', 'Switzerland', 'Australia', 'New Zealand',
#        'Costa Rica', 'Kuwait', 'Austria', 'Canada', 'Belgium', 'Ireland',
#        'Czechia', 'Lithuania', 'United Kingdom', 'Slovenia',
#        'United Arab Emirates', 'United States', 'Germany', 'Mexico',
#        'Uruguay', 'France', 'Saudi Arabia', 'Kosovo', 'Singapore',
#        'Taiwan Province of China', 'Romania', 'El Salvador', 'Estonia',
#        'Poland', 'Spain', 'Serbia', 'Chile', 'Panama', 'Malta', 'Italy',
#        'Guatemala', 'Nicaragua', 'Brazil', 'Slovakia', 'Latvia',
#        'Uzbekistan', 'Argentina', 'Kazakhstan', 'Cyprus', 'Japan',
#        'South Korea', 'Philippines', 'Vietnam', 'Portugal', 'Hungary',
#        'Paraguay', 'Thailand', 'Malaysia', 'China', 'Honduras', 'Bahrain',
#        'Croatia', 'Greece', 'Bosnia and Herzegovina', 'Libya', 'Jamaica',
# ...

# %%
df['Regional indicator'].unique()
# Out:
# array(['Western Europe', 'Middle East and North Africa',
#        'North America and ANZ', 'Latin America and Caribbean',
#        'Central and Eastern Europe', 'Southeast Asia', 'East Asia',
#        'Commonwealth of Independent States', 'Sub-Saharan Africa',
#        'South Asia'], dtype=object)

# %%
df['Ladder score'].max()
# Out:
# 7.741

# %%
common_region = df['Regional indicator'].mode()[0]
print(common_region)
# Out:
# Sub-Saharan Africa

# %%
plt.boxplot(df['Ladder score'])
plt.show()

# %%
plt.hist(df['Ladder score'].dropna(), bins=20, color='skyblue', edgecolor='black')
plt.xlabel('Happiness score')
plt.ylabel('Frequency')
plt.title('Distribution of Happiness Scores')
plt.show()

# %%
df[['Country name','Ladder score']].sort_values(by='Ladder score',ascending=False).head(10)
# Out:
#   Country name  Ladder score
# 0      Finland         7.741
# 1      Denmark         7.583
# 2      Iceland         7.525
# 3       Sweden         7.344
# 4       Israel         7.341
# 5  Netherlands         7.319
# 6       Norway         7.302
# 7   Luxembourg         7.122
# 8  Switzerland         7.060
# 9    Australia         7.057

# %%
mean_ladder = df.groupby('Regional indicator').agg({'Ladder score': 'mean'})
sort_ladder = mean_ladder.sort_values(by='Ladder score', ascending=True)
plt.bar(sort_ladder.index, sort_ladder['Ladder score'], color='orange', edgecolor='black')
plt.xticks(rotation=90)
plt.ylabel('Average Ladder score')
plt.title('Average Happiness Score per Region')
plt.show()

# %%
df
# Out:
#          Country name            Regional indicator  Ladder score  \
# 0             Finland                Western Europe         7.741
# 1             Denmark                Western Europe         7.583
# 2             Iceland                Western Europe         7.525
# 3              Sweden                Western Europe         7.344
# 4              Israel  Middle East and North Africa         7.341
# ..                ...                           ...           ...
# 138  Congo (Kinshasa)            Sub-Saharan Africa         3.295
# 139      Sierra Leone            Sub-Saharan Africa         3.245
# 140           Lesotho            Sub-Saharan Africa         3.186
# 141           Lebanon  Middle East and North Africa         2.707
# 142       Afghanistan                    South Asia         1.721
#
#      upperwhisker  lowerwhisker  Log GDP per capita  Social support  \
# 0           7.815         7.667               1.844           1.572
# ...

# %%
plt.scatter(df['Log GDP per capita'], df['Ladder score'],color='pink', edgecolor='black', alpha=0.7)
plt.xlabel("Log GDP per capita")
plt.ylabel("Ladder score")
plt.title('Log GDP per capita vs Ladder score')
plt.show()

# %%
group_score=df.groupby('Regional indicator')['Ladder score'].mean()
plt.boxplot(group_score.values)
plt.xlabel('Average Ladder Score')
plt.show()

# %%
print("Mean : ",round(df['Ladder score'].mean(),2))
print("Median : ",round(df['Ladder score'].median(),2))
print("Mode : ",round(df['Ladder score'].mode(),2))
# Out:
# Mean :  5.53
# Median :  5.79
# Mode :  0    3.50
# 1    5.82
# 2    6.19
# Name: Ladder score, dtype: float64

# %%
print("Variance : ",round(df['Ladder score'].var(),2))
print("Standard deviation : ",round(df['Ladder score'].std(),2))
# Out:
# Variance :  1.37
# Standard deviation :  1.17

# %%
avg=df['Ladder score'].mean()
avg_less=df[df['Ladder score']<avg]['Country name'].nunique()
tot=df['Country name'].nunique()
per=(avg_less*100)/tot
print(round(per,2))
# Out:
# 44.06

# %%
df.sort_values(by='Ladder score',ascending=False).head(20)
# Out:
#       Country name            Regional indicator  Ladder score  upperwhisker  \
# 0          Finland                Western Europe         7.741         7.815
# 1          Denmark                Western Europe         7.583         7.665
# 2          Iceland                Western Europe         7.525         7.618
# 3           Sweden                Western Europe         7.344         7.422
# 4           Israel  Middle East and North Africa         7.341         7.405
# 5      Netherlands                Western Europe         7.319         7.383
# 6           Norway                Western Europe         7.302         7.389
# 7       Luxembourg                Western Europe         7.122         7.213
# 8      Switzerland                Western Europe         7.060         7.147
# 9        Australia         North America and ANZ         7.057         7.141
# 10     New Zealand         North America and ANZ         7.029         7.105
# ...

# %%
df['Ladder score'].isna().sum()
# Out:
# np.int64(0)

# %%
df.loc[:, 'Ladder score'] = pd.to_numeric(df['Ladder score'], errors='coerce')
if df['Ladder score'].notna().any():
    median_val = df['Ladder score'].median(skipna=True)
else:
    median_val = 0 
df.loc[:, 'Ladder score'] = df['Ladder score'].fillna(median_val)

# %%
df.loc[:, 'Log GDP per capita'] = pd.to_numeric(df['Log GDP per capita'], errors='coerce')
if df['Log GDP per capita'].notna().any():
    median_val = df['Log GDP per capita'].median(skipna=True)
else:
    median_val = 0
df.loc[:, 'Log GDP per capita'] = df['Log GDP per capita'].fillna(median_val)

# %%
ladder_score = np.array(df['Ladder score'])
logged_gdp_per_capita = np.array(df['Log GDP per capita'])

# %%
vec_add=ladder_score+logged_gdp_per_capita
vec_sub=ladder_score-logged_gdp_per_capita
print("Add:",vec_add)
print("\n")
print("Sub:",vec_sub)
# Out:
# Add: [9.585  9.491  9.406  9.222  9.144  9.22   9.254  9.263  9.03   8.911
#  8.839  8.516  8.796  8.79   8.74   8.762  8.967  8.605  8.584  8.571
#  8.529  8.716  8.664  8.59   8.199  8.207  8.427  8.436  7.925  8.641
#  8.345  8.19   7.734  8.2    8.18   8.187  7.949  7.976  8.06   8.173
#  8.124  7.547  7.381  7.702  7.963  7.934  7.407  7.75   7.81   7.862
#  7.846  7.873  7.28   7.374  7.758  7.739  7.375  7.46   7.621  7.47
#  7.059  7.3905 7.652  7.618  7.342  7.392  7.122  7.212  7.34   7.386
#  7.201  7.427  7.001  7.04   6.768  7.278  7.049  7.132  5.607  6.929
#  7.092  6.899  6.811  6.844  6.688  7.225  6.742  6.7125 6.113  5.776
#  6.652  6.415  6.123  6.347  6.509  6.16   5.854  6.677  5.896  6.358
#  6.326  5.923  6.3105 5.817  6.223  6.098  6.008  5.726  5.129  5.304
#  5.583  5.235  5.074  5.507  5.728  5.291  5.144  5.332  5.352  5.366
#  4.888  4.979  4.856  4.972  5.448  5.22   5.347  5.259  5.008  4.653
# ...

# %%
print(round(np.dot(ladder_score,logged_gdp_per_capita),2))
# Out:
# 1144.36

# %%
df.columns
# Out:
# Index(['Country name', 'Regional indicator', 'Ladder score', 'upperwhisker',
#        'lowerwhisker', 'Log GDP per capita', 'Social support',
#        'Healthy life expectancy', 'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Dystopia + residual'],
#       dtype='object')

# %%
df['Social support'].isna().sum()
# Out:
# np.int64(3)

# %%
df.loc[:, 'Social support'] = pd.to_numeric(df['Social support'], errors='coerce')
if df['Social support'].notna().any():
    median_val = df['Social support'].median(skipna=True)
else:
    median_val = 0
df.loc[:, 'Social support'] = df['Social support'].fillna(median_val)

# %%
matrix=np.array(df[['Log GDP per capita','Social support']])
weighs=np.array([0.5,0.5])
wei_mat=np.dot(matrix,weighs)
print(wei_mat)
# Out:
# [1.708  1.714  1.749  1.6895 1.658  1.6815 1.7345 1.748  1.6975 1.6575
#  1.6685 1.467  1.6045 1.6105 1.6495 1.654  1.7595 1.647  1.61   1.574
#  1.644  1.5735 1.6655 1.6305 1.381  1.5135 1.583  1.6015 1.3205 1.7395
#  1.594  1.4675 1.1725 1.6395 1.5775 1.6185 1.4645 1.4925 1.547  1.6355
#  1.564  1.2145 1.18   1.3495 1.623  1.604  1.303  1.4715 1.5395 1.5055
#  1.57   1.4965 1.189  1.299  1.548  1.625  1.403  1.4155 1.3945 1.368
#  1.063  1.3345 1.5775 1.48   1.3915 1.313  1.302  1.2755 1.3945 1.464
#  1.331  1.4965 1.198  1.233  1.2655 1.4445 1.432  1.339  0.6605 1.2725
#  1.549  1.299  1.379  1.376  1.2575 1.5465 1.181  1.3345 0.757  0.7215
#  1.2285 1.1225 0.9775 1.027  1.2205 0.829  0.7265 1.4385 0.839  1.2855
#  1.1545 1.0585 1.3345 0.8995 1.3325 1.239  0.842  0.8345 0.625  0.7205
#  0.8915 0.717  0.704  0.966  1.1305 0.521  0.9615 0.983  1.015  0.912
#  0.646  0.7175 0.7255 0.672  1.1225 0.9095 1.183  1.27   0.6855 0.8535
# ...

# %%
ladder_score = df['Ladder score'].to_numpy(dtype=float)
min_val = ladder_score.min()
max_val = ladder_score.max()
normalized_ladder_score = (ladder_score - min_val) / (max_val - min_val)
print(normalized_ladder_score)
# Out:
# [1.         0.97375415 0.9641196  0.93405316 0.93355482 0.92990033
#  0.92707641 0.89717608 0.88687708 0.88637874 0.88172757 0.86943522
#  0.86877076 0.86112957 0.860299   0.85930233 0.85       0.84734219
#  0.84667774 0.83521595 0.83421927 0.83255814 0.83122924 0.83023256
#  0.82342193 0.81229236 0.81196013 0.80946844 0.80398671 0.79767442
#  0.79435216 0.7923588  0.78870432 0.78521595 0.78421927 0.7807309
#  0.77906977 0.77059801 0.77026578 0.76827243 0.76461794 0.75847176
#  0.75797342 0.75598007 0.75348837 0.74966777 0.74318937 0.74202658
#  0.74202658 0.72209302 0.72076412 0.72043189 0.71877076 0.7179402
#  0.71578073 0.71362126 0.70697674 0.70681063 0.70664452 0.70631229
#  0.70548173 0.70398671 0.70116279 0.69983389 0.69036545 0.68853821
#  0.6845515  0.68438538 0.68139535 0.68023256 0.68023256 0.67508306
#  0.67491694 0.66511628 0.66328904 0.66212625 0.660299   0.66013289
#  0.64551495 0.63903654 0.62159468 0.62026578 0.61478405 0.60598007
# ...

# %%
import sympy as sp

# %%
GDP, H = sp.symbols('GDP H')
Wellbeing_Index = (GDP * H) + 0.5 * (H - 5)**2
derivative = sp.diff(Wellbeing_Index, H)
print("Derivative:", derivative)
# Out:
# Derivative: GDP + 1.0*H - 5.0

# %%
df['is_happy'] = (df['Ladder score'] > 7).astype(int)

# %%
df['happiness_rank'] = df['Ladder score'].rank(ascending=False, method='min').astype(int)

# %%
global_mean_gdp = df['Log GDP per capita'].mean()
df['above_average_gdp'] = (df['Log GDP per capita'] > global_mean_gdp).astype(int)

# %%
df[df['Healthy life expectancy'].isna()]
# Out:
#            Country name                  Regional indicator  Ladder score  \
# 61              Bahrain        Middle East and North Africa         5.959
# 87           Tajikistan  Commonwealth of Independent States         5.281
# 102  State of Palestine        Middle East and North Africa         4.879
#
#      upperwhisker  lowerwhisker  Log GDP per capita  Social support  \
# 61          6.153         5.766              1.4315          1.2375
# 87          5.361         5.201              1.4315          1.2375
# 102         5.006         4.753              1.4315          1.2375
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 61                       NaN                           NaN         NaN
# 87                       NaN                           NaN         NaN
# 102                      NaN                           NaN         NaN
#
#      Perceptions of corruption  Dystopia + residual  is_happy  happiness_rank  \
# ...

# %%
df.loc[:, 'Healthy life expectancy'] = pd.to_numeric(df['Healthy life expectancy'], errors='coerce')
if df['Healthy life expectancy'].notna().any():
    median_val = df['Healthy life expectancy'].median(skipna=True)
else:
    median_val = 0
df.loc[:,'Healthy life expectancy'] = df['Healthy life expectancy'].fillna(median_val)

# %%
df['life_expectancy_quartile'] = pd.qcut(df['Healthy life expectancy'], q=4,labels=[1, 2, 3, 4]).astype(int)

# %%
df[df['Ladder score']>7]
# Out:
#    Country name            Regional indicator  Ladder score  upperwhisker  \
# 0       Finland                Western Europe         7.741         7.815
# 1       Denmark                Western Europe         7.583         7.665
# 2       Iceland                Western Europe         7.525         7.618
# 3        Sweden                Western Europe         7.344         7.422
# 4        Israel  Middle East and North Africa         7.341         7.405
# 5   Netherlands                Western Europe         7.319         7.383
# 6        Norway                Western Europe         7.302         7.389
# 7    Luxembourg                Western Europe         7.122         7.213
# 8   Switzerland                Western Europe         7.060         7.147
# 9     Australia         North America and ANZ         7.057         7.141
# 10  New Zealand         North America and ANZ         7.029         7.105
#
#     lowerwhisker  Log GDP per capita  Social support  Healthy life expectancy  \
# ...

# %%
df.sort_values(by='Log GDP per capita', ascending=False, inplace=True)
df
# Out:
#              Country name            Regional indicator  Ladder score  \
# 7              Luxembourg                Western Europe         7.122
# 16                Ireland                Western Europe         6.838
# 29              Singapore                Southeast Asia         6.523
# 21   United Arab Emirates  Middle East and North Africa         6.733
# 8             Switzerland                Western Europe         7.060
# ..                    ...                           ...           ...
# 112                  Chad            Sub-Saharan Africa         4.471
# 108                 Niger            Sub-Saharan Africa         4.556
# 89             Mozambique            Sub-Saharan Africa         5.216
# 138      Congo (Kinshasa)            Sub-Saharan Africa         3.295
# 78              Venezuela   Latin America and Caribbean         5.607
#
#      upperwhisker  lowerwhisker  Log GDP per capita  Social support  \
# ...

# %%
avg_happiness_by_region = df.groupby('Regional indicator')['Ladder score'].mean().reset_index().rename(columns={'Ladder score': 'avg_happiness_score'})
print(avg_happiness_by_region)
# Out:
#                    Regional indicator  avg_happiness_score
# 0          Central and Eastern Europe             6.170941
# 1  Commonwealth of Independent States             5.538500
# 2                           East Asia             5.934333
# 3         Latin America and Caribbean             6.143368
# 4        Middle East and North Africa             5.199941
# 5               North America and ANZ             6.927750
# 6                          South Asia             3.895667
# 7                      Southeast Asia             5.551889
# 8                  Sub-Saharan Africa             4.329686
# 9                      Western Europe             6.841650

# %%
top5_regions = df.groupby('Regional indicator')['Ladder score'].mean().reset_index().rename(columns={'Ladder score': 'avg_happiness_score'}).sort_values(by='avg_happiness_score', ascending=False).head(5)
print(top5_regions)
# Out:
#             Regional indicator  avg_happiness_score
# 5        North America and ANZ             6.927750
# 9               Western Europe             6.841650
# 0   Central and Eastern Europe             6.170941
# 3  Latin America and Caribbean             6.143368
# 2                    East Asia             5.934333

# %%
print(df[df['Healthy life expectancy']>70])
# Out:
# Empty DataFrame
# Columns: [Country name, Regional indicator, Ladder score, upperwhisker, lowerwhisker, Log GDP per capita, Social support, Healthy life expectancy, Freedom to make life choices, Generosity, Perceptions of corruption, Dystopia + residual, is_happy, happiness_rank, above_average_gdp, life_expectancy_quartile]
# Index: []

# %%
happiest_country = df.loc[df['Ladder score'].idxmax(), 'Country name']
print(happiest_country)
# Out:
# Finland

# %%
happiest_region = df.groupby('Regional indicator')['Ladder score'].mean().idxmax()
print(happiest_country)
# Out:
# Finland

# %%
gdp_happiness_corr = df['Log GDP per capita'].corr(df['Ladder score'])
print(gdp_happiness_corr)
# Out:
# 0.7667075351351104

# %%
df[(df['Log GDP per capita'] > df['Log GDP per capita'].mean()) & (df['Ladder score'] < df['Ladder score'].mean())]
# Out:
#                   Country name                  Regional indicator  \
# 85   Hong Kong S.A.R. of China                           East Asia
# 97                     Turkiye        Middle East and North Africa
# 80                    Bulgaria          Central and Eastern Europe
# 83             North Macedonia          Central and Eastern Europe
# 90                     Georgia  Commonwealth of Independent States
# 136                   Botswana                  Sub-Saharan Africa
# 81                     Armenia  Commonwealth of Independent States
# 86                     Albania          Central and Eastern Europe
# 99                        Iran        Middle East and North Africa
# 100                 Azerbaijan  Commonwealth of Independent States
# 87                  Tajikistan  Commonwealth of Independent States
# 102         State of Palestine        Middle East and North Africa
# 94                       Gabon                  Sub-Saharan Africa
# ...

# %%
df.groupby('Regional indicator')['Healthy life expectancy'].mean().idxmax()
# Out:
# 'Western Europe'

# %% [markdown]
# Extra analysis

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()
#Ladder score will likely have high positive correlation with GDP, Social support, and Life expectancy.
#Perceptions of corruption may have a negative correlation.

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Freedom to make life choices', y='Ladder score', hue='Regional indicator', data=df)
plt.title("Happiness vs Freedom")
plt.show()


#Countries with higher freedom  tend to be happier.

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Perceptions of corruption', y='Ladder score', hue='Regional indicator', data=df)
plt.title("Happiness vs Corruption Perception")
plt.show()
#Country with less corruption -- happier

# %%
df.groupby('Regional indicator')['Ladder score'].mean().plot(kind='bar', figsize=(12, 6))
plt.title("Average Happiness by Region")
plt.ylabel("Average Ladder Score")
plt.show()

#track happiness change per region

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='Regional indicator', y='Ladder score', data=df)
plt.title("Happiness Distribution by Region")
plt.xticks(rotation=90)
plt.show()
#This shows which regions have outliers in happiness.

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(x='Log GDP per capita', y='Ladder score', hue='Regional indicator', data=df, s=100)
plt.title("Happiness vs GDP per Region")
plt.show()
#Regions have rich but less happy countries or poor but happier countries.

# %%
region_std = df.groupby('Regional indicator')['Ladder score'].std().sort_values(ascending=False)
print(region_std)
region_std.plot(kind='bar', title='Happiness Score Standard Deviation by Region')
plt.show()
#Higher standard deviation means larger happiness gap between countries in the same region.
# Out:
# Regional indicator
# Middle East and North Africa          1.260354
# South Asia                            1.177069
# Southeast Asia                        0.779519
# Sub-Saharan Africa                    0.704075
# Western Europe                        0.538030
# Central and Eastern Europe            0.494803
# Commonwealth of Independent States    0.480649
# East Asia                             0.398773
# Latin America and Caribbean           0.376936
# North America and ANZ                 0.151476
# Name: Ladder score, dtype: float64
